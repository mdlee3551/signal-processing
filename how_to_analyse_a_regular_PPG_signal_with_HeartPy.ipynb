# %%
import heartpy as hp
import matplotlib.pyplot as plt

# %% [markdown]
# HeartPy comes with a function load_exampledata() that can load the datasets provided.
#
# Three datasets included with HeartPy:
#
# 0 : a short, very clean PPG signal, sampled at 100.0 Hz
#
# 1 : a slightly longer (~2 minute) PPG signal, with missing signal in first third, and random noise spikes in rest of signal
#
# 2 : a long (~11.5 minute) PPG signal recorded 'in the wild' while driving in a driving simulator using a Pulse Sensor on the index finger and an Arduino

# %%
#first let's load the clean PPG signal
data, timer = hp.load_exampledata(0)

#and visualise
plt.figure(figsize=(12,4))
plt.plot(data)
plt.show()

# %%
#run the analysis
wd, m = hp.process(data, sample_rate = 100.0)

#wd: A waveform dictionary containing processed data.
#m: A dictionary containing computed measures such as heart rate.

#set large figure
plt.figure(figsize=(12,4))

#call plotter
hp.plotter(wd, m)

#display measures computed
for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))
# Out:
# bpm: 58.898848
# ibi: 1018.695652
# sdnn: 65.760061
# sdsd: 34.866925
# rmssd: 64.737231
# pnn20: 0.863636
# pnn50: 0.409091
# hr_mad: 40.000000
# sd1: 45.758077
# sd2: 82.926832
# s: 11921.000816
# sd1/sd2: 0.551789
# breathingrate: 0.170721

# %%
data, timer = hp.load_exampledata(1)

plt.figure(figsize=(12,4))
plt.plot(data)
plt.show()
